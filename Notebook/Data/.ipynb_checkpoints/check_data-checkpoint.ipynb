# %%
library(Seurat)
library(qs)
# Out:
# Loading required package: SeuratObject
#
# Loading required package: sp
#
# ‘SeuratObject’ was built with package ‘Matrix’ 1.7.0 but the current
# version is 1.7.2; it is recomended that you reinstall ‘SeuratObject’ as
# the ABI for ‘Matrix’ may have changed
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, t
#
#
# qs 0.27.2. Announcement: https://github.com/qsbase/qs/issues/103

# %%
p3f_dosages_2wks <- readRDS("./in/seurat_obj/p3f_dosages_2wks.rds")
p3f_removal_postqc <- readRDS("./in/seurat_obj/p3f_removal_postqc.rds")
p3f_removal_singleR_ann <- readRDS("./in/seurat_obj/p3f_removal_singleR_ann.rds")

# %%
p3f_dosages_2wks
p3f_removal_postqc
p3f_removal_singleR_ann
# Out:
# An object of class Seurat
# 20080 features across 24501 samples within 1 assay
# Active assay: RNA (20080 features, 2000 variable features)
#  3 layers present: counts, data, scale.data
#  3 dimensional reductions calculated: pca, umap, harmony
# An object of class Seurat
# 23016 features across 36919 samples within 1 assay
# Active assay: RNA (23016 features, 0 variable features)
#  3 layers present: counts.SEG0503, counts.SEG0504, counts.SEG0505
# An object of class Seurat
# 23016 features across 36919 samples within 1 assay
# Active assay: RNA (23016 features, 2000 variable features)
#  3 layers present: counts, data, scale.data
#  3 dimensional reductions calculated: pca, umap, harmony

# %%
head(p3f_dosages_2wks@meta.data)
# Out:
#                          orig.ident    nCount_RNA nFeature_RNA percent.mt
# AAACCCAAGGTAGCAC-1_2_1_1 SeuratProject  8496      2488         1.494821
# AAACCCACAAGAGGTC-1_2_1_1 SeuratProject 11737      3298         2.760501
# AAACCCACAATGAACA-1_2_1_1 SeuratProject 15256      3769         2.648138
# AAACCCACACCTAAAC-1_2_1_1 SeuratProject 13171      4045         2.680131
# AAACCCACATGCAGCC-1_2_1_1 SeuratProject  8244      2674         2.316836
# AAACCCAGTAACCAGG-1_2_1_1 SeuratProject 15032      3622         2.687600
#                          condition log10GenesPerUMI seurat_clusters S.Score
# AAACCCAAGGTAGCAC-1_2_1_1 Dbt-0-2wk 0.8642568        0               -0.1304060
# AAACCCACAAGAGGTC-1_2_1_1 Dbt-0-2wk 0.8645291        0               -0.1310312
# AAACCCACAATGAACA-1_2_1_1 Dbt-0-2wk 0.8548528        4               -0.1798180
# AAACCCACACCTAAAC-1_2_1_1 Dbt-0-2wk 0.8755467        4               -0.1678906
# ...

# %%
head(p3f_removal_postqc@meta.data)
# Out:
#                           orig.ident nCount_RNA nFeature_RNA percent.mt
# SEG503_AAACCCAAGAAGTCAT-1 SEG0503     5796      2458         4.658385
# SEG503_AAACCCAAGGAATCGC-1 SEG0503    20641      5489         4.738143
# SEG503_AAACCCAAGTAATTGG-1 SEG0503    21549      5680         5.387721
# SEG503_AAACCCACAGCCCACA-1 SEG0503    17007      5421         3.780796
# SEG503_AAACCCACATTCAGCA-1 SEG0503    23659      5672         5.334122
# SEG503_AAACCCATCACTTGGA-1 SEG0503    24531      5758         3.094044
#                           log10GenesPerUMI
# SEG503_AAACCCAAGAAGTCAT-1 0.9010009
# SEG503_AAACCCAAGGAATCGC-1 0.8666806
# SEG503_AAACCCAAGTAATTGG-1 0.8663693
# SEG503_AAACCCACAGCCCACA-1 0.8826301
# SEG503_AAACCCACATTCAGCA-1 0.8581937
# SEG503_AAACCCATCACTTGGA-1 0.8566095

# %%
head(p3f_removal_singleR_ann@meta.data)
# Out:
#                           orig.ident nCount_RNA nFeature_RNA percent.mt
# SEG503_AAACCCAAGAAGTCAT-1 SEG0503     5796      2458         4.658385
# SEG503_AAACCCAAGGAATCGC-1 SEG0503    20641      5489         4.738143
# SEG503_AAACCCAAGTAATTGG-1 SEG0503    21549      5680         5.387721
# SEG503_AAACCCACAGCCCACA-1 SEG0503    17007      5421         3.780796
# SEG503_AAACCCACATTCAGCA-1 SEG0503    23659      5672         5.334122
# SEG503_AAACCCATCACTTGGA-1 SEG0503    24531      5758         3.094044
#                           log10GenesPerUMI S.Score    G2M.Score   Phase
# SEG503_AAACCCAAGAAGTCAT-1 0.9010009        0.15915266  0.13525410 S
# SEG503_AAACCCAAGGAATCGC-1 0.8666806        0.10455204 -0.18610886 S
# SEG503_AAACCCAAGTAATTGG-1 0.8663693        0.07326734  0.05827505 S
# SEG503_AAACCCACAGCCCACA-1 0.8826301        0.35113299 -0.07584839 S
# SEG503_AAACCCACATTCAGCA-1 0.8581937        0.40407499 -0.12167554 S
# SEG503_AAACCCATCACTTGGA-1 0.8566095        0.17503419 -0.02390098 S
# ...

# %%
options(repr.plot.width=20, repr.plot.height=8)

p1 <- DimPlot(p3f_dosages_2wks)
p2 <- DimPlot(p3f_removal_singleR_ann)

p1 | p2
# Out:
# plot without title
